# %% [markdown]
# # Standard Genetic Programming Algorithm
#
# In this assignment we are going to explore the symbolic regression using Genetic Programming. The idea of symbolic regression is to discover a mathematical expression or equation that best represents the underlying relationship between variables in a dataset. This involves finding a balance between accuracy, i.e. fitting the data well, and simplicity, i.e. ensuring the expression is interpretable and generalizes to new data. We will be doing symbolic regression resorting to tree based Genetic Programming, an evolutionary algorithm type as you learn in class. The problem at hand is to create a mathematical expression that minimizes the error between the predicted values and the observed data points in the given dataset.

# %% [markdown]
# ## Assignment Task (MUST READ)
#
# 1. Analyse the implementations bellow for symbolic regression using Genetic Programming. The code is ready to run on one dataset (datasetSimple).
#
# 2. Implement the following:
# - 2.1 Only a simple base of terminals and functions are implemented. Expand by implementing other functions and terminals that you see fit for the problem. Do some trial runs to test and validate your expanded set, however create and choose at most **one more set** of terminals and functions for points 3. and 4. .
# - 2.2 Add the elitism mechanism.
# - 2.3 Implement and add the point mutation operator. The idea is to have a probability of using either subtree mutaton or point mutation during the mutation operation.
# - 2.4 Create a fitness function with bloat control.
#
# 3. Run experiments on **datasetSimple** and **datasetHard** and analyse the following setups:
# - 3.1 elistism **vs** no elitism
# - 3.2 simple terminals and functions **vs** implemented expanded set of functions and terminals.
# - 3.4 normal fitness function **vs** fitness function with bloat control.
#
# Note: for all experiments run **5 different random seeds**
#
# 4. Analyse the results from the experiments by reporting in this notebook. The analysis for each experiment should take into account:
# - 4.1 best fitness value, but provide the plot generation/fitness (x/y)
# - 4.2 number of generations needed to reach the minimum aceptable error value (<= 1e-6) . Note that different seeds or configurations can terminate before the defined number o generations.
# - 4.3 the size of the three (number of nodes) and depth.
#
#
# In the end, you should indicate the best setup that you found for each dataset.
#
# Note: Resort to the tehoretical slides and like in the first assignment, in order to analyse and draw conclusions you **must run the same setup multiple times with different random seeds**.
#
# Further reading:
#
# Field guide to Genetic Programming: http://www0.cs.ucl.ac.uk/staff/W.Langdon/ftp/papers/poli08_fieldguide.pdf

# %% [markdown]
# ### CODE

# %%
# Adaptation of the Tiny-GP code available at https://github.com/moshesipper/tiny_gp/blob/master/tiny_gp.py
from random import random, randint, seed
from statistics import mean
from copy import deepcopy
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # Definition of the Terminal and Non-Terminal Symbols
# In this section, you are expected to define terminal and non-terminal (functions) symbols of the Genetic Programming approach. Some of them are already defined.

# %%
# TODO update and add code here
# ---------------------------
# Function Definitions
# ---------------------------

def add(x, y):
    return x + y
add.arity = 2

def sub(x, y):
    return x - y
sub.arity = 2

def mul(x, y):
    return x * y
mul.arity = 2

def div(x, y):
    if y == 0:
        return -1 # valor minimo do dominio
    return x / y
div.arity = 2


# def square(x):
#     return x ** 2
# square.arity = 1

# def cube(x):
#     return x ** 3
# cube.arity = 1

def sqrt(x):
    if x < 0:
        return -1 # valor minimo do dominio
    return np.sqrt(abs(x))
sqrt.arity = 1

def log(x):
    if x <= 0:
        return -1 # valor minimo do dominio
    return np.log(abs(x))
log.arity = 1

# ---------------------------
# Terminals and Function List
# ---------------------------
TERMINALS = ['x', -2, -1, 0, 1, 2]
FUNCTIONS  = [add, sub, mul, div, sqrt, log] # podemos ainda adicionar square e cube

# expanded set
#EXPANDED_FUNCTIONS = [...]
#EXPANDED_TERMINALS = [...] 

FUNCTIONS = FUNCTIONS #EXPANDED_FUNCTIONS
TERMINALS = TERMINALS #EXPANDED_TERMINALS

# %% [markdown]
# # Parameters
#
# These are the base evolutionary parameters.

# %%
POP_SIZE        = 50   # population size
MIN_DEPTH       = 2    # minimal initial random tree depth
MAX_DEPTH       = 6   # maximal initial random tree depth
GENERATIONS     = 100  # maximal number of generations to run evolution
TOURNAMENT_SIZE = 5    # size of tournament for tournament selection
XO_RATE         = 0.8  # crossover rate 
PROB_MUTATION   = 0.2  # per-node mutation probability 
ELISTIM = 0.1 #0

# %% [markdown]
# # Representation of a Program using a GP Tree
# Analyze the following code. This is the base code, and some parts will require updates to fulfill the assignment.

# %%
import random
from random import randint, random

class GPTree:
    def __init__(self, data=None, children=None):
        self.data = data
        # Use a list for children; if not provided, initialize as empty.
        self.children = children if children is not None else []

    def node_label(self):
        if self.data in FUNCTIONS:
            return self.data.__name__
        else:
            return str(self.data)

    def print_tree(self, prefix=""):
        print(f"{prefix}{self.node_label()}")
        for child in self.children:
            child.print_tree(prefix + "   ")

    def compute_tree(self, x):
        # If the node holds a function, compute all its children first.
        if self.data in FUNCTIONS:
            args = [child.compute_tree(x) for child in self.children]
            return self.data(*args)
        elif self.data == 'x':
            return x
        else:
            return self.data

    def random_tree(self, grow, max_depth, depth=0):
        # Decide whether this node will be a function or a terminal.
        if depth < MIN_DEPTH or (depth < max_depth and not grow):
            self.data = FUNCTIONS[randint(0, len(FUNCTIONS) - 1)]
        elif depth >= max_depth:
            self.data = TERMINALS[randint(0, len(TERMINALS) - 1)]
        else:
            if random() > 0.5:
                self.data = TERMINALS[randint(0, len(TERMINALS) - 1)]
            else:
                self.data = FUNCTIONS[randint(0, len(FUNCTIONS) - 1)]
        # If the node is a function, create as many children as its arity
        if self.data in FUNCTIONS:
            self.children = []
            for _ in range(self.data.arity):
                child = GPTree()
                child.random_tree(grow, max_depth, depth + 1)
                self.children.append(child)

    def mutation(self):
        if random() < PROB_MUTATION:
            # Replace this subtree with a new random tree (of limited depth)
            self.random_tree(grow=True, max_depth=2)
        else:
            for child in self.children:
                child.mutation()

    def size(self):
        if self.data not in FUNCTIONS:
            return 1
        return 1 + sum(child.size() for child in self.children)

    def build_subtree(self):
        t = GPTree()
        t.data = self.data
        t.children = [child.build_subtree() for child in self.children]
        return t

    def scan_tree(self, count, second):
        count[0] -= 1
        if count[0] <= 1:
            if not second:
                return self.build_subtree()
            else:
                self.data = second.data
                self.children = second.children
        else:
            ret = None
            for child in self.children:
                if count[0] > 1:
                    ret = child.scan_tree(count, second)
            return ret

    def crossover(self, other):
        if random() < XO_RATE:
            second = other.scan_tree([randint(1, other.size())], None)
            self.scan_tree([randint(1, self.size())], second)

# %% [markdown]
# # Fitness Evaluation
# You have to adjust this code in order to introduce bloat control mechanism. You should maintain the version without bloat control for comparison.

# %%
# *** YOUR CODE HERE ***
# You are going to need to add another function in order to introduce a bloat control mechanism. Adapt the existing one. 
# SEGUNDO PASSO: Mais nós: penalizar
# Adicionar uma penalização para árvores maiores
# na fitness, equilibrar o erro e o mecanismo de bloat control que deve estar entre 0 e 1
# bloat control: 0 -> árvore pequena; 1 -> árvore grande
def calculate_error(individual, dataset):
    return mean([abs(individual.compute_tree(ds[0]) - ds[1]) for ds in dataset])

def bloat(individual):
    # Arvores maiores devem ser penalizadas (bloat control). penalti mais perto de zero se é pequena e mais perto de 1 se é grande
    return (individual.size() / 100)

def fitness(individual, dataset, bloat_control = True): # mean absolute error over dataset normalized to [0,1] # MUDAR BLOAT CONTROL (SE É TRUE OU FALSE)
    if bloat_control:
        #print("bloat control: " + str(bloat(individual)))
        return calculate_error(individual, dataset) + bloat(individual)
    else:
        return calculate_error(individual, dataset)

# %% [markdown]
# # Parent Selection
# The selection mechanism implemented is the tournament selection.

# %%
def selection(population, fitnesses): # select one individual using tournament selection
    tournament = [randint(0, len(population)-1) for i in range(TOURNAMENT_SIZE)] # select tournament contenders
    tournament_fitnesses = [fitnesses[tournament[i]] for i in range(TOURNAMENT_SIZE)]
    return deepcopy(population[tournament[tournament_fitnesses.index(min(tournament_fitnesses))]])

# %% [markdown]
# # Survivor Selection
# The implementation of elistism should be done here, check the code, follow the instructions and complete the code.

# %%
def survivors_selection_elite(parents,offspring, elite):
    #This Function Should then be called in the Main Cycle line 23, i.e. it should replace the generational mechanism that is currectly in place
    size = len(parents)
    elite_size = int(size* elite)
    new_population = []
    # ******* YOUR CODE HERE *******
    # PRIMEIRO PASSO
    # Consoante o elitismo, selecionar o que vem dos parents e o que vem dos offspring
    # Elitismo
    if elite_size > 0:
        new_population = parents[:elite_size] + offspring[:size-elite_size]
    else:
        new_population = offspring
    return new_population

# %% [markdown]
# # Generate Inital Population using Ramped Half-and-Half
# Ramped half-and-half is a method for initializing populations, where half of the individuals are generated using a "full" method (producing complete trees up to a specified depth), and the other half are created using a "grow" method (producing trees of varying shapes and depths), ensuring diversity in the initial population.

# %%
# Generate an individual: method full or grow
# Field Guide Genetic Programming: algorithm 2.1, pg.14
def init_population():
    pop = []
    for md in range(3, MAX_DEPTH + 1):
        for i in range(int(POP_SIZE/6)):
            t = GPTree()
            t.random_tree(grow = True, max_depth = md) # grow
            pop.append(t) 
        for i in range(int(POP_SIZE/6)):
            t = GPTree()
            t.random_tree(grow = False, max_depth = md) # full
            pop.append(t)
    #If we are missing some inviduals, just fill the rest of population with random trees with the full method
    print(len(pop))
    if len(pop) < POP_SIZE: 
        for i in range(POP_SIZE - len(pop)):
            t = GPTree()
            t.random_tree(grow = False, max_depth = md) # full
            pop.append(t)
    elif len(pop) > POP_SIZE:
        pop = pop[:POP_SIZE]
    
    print(len(pop))
    return pop

# %% [markdown]
# # Main Cycle

# %%
def standard_gp(dataset, verbose=False):      
    # init stuff
    seed() # init internal state of random number generator
    population= init_population() 
    best_of_run = None
    best_of_run_f = 999999.0
    best_of_run_gen = 999999.0
    best_per_generation = []
    fitnesses = [fitness(population[i], dataset) for i in range(POP_SIZE)]

    # go evolution!
    for gen in range(GENERATIONS):  
        if verbose: print("Generation: %d" % gen)
        nextgen_population=[]
        for i in range(POP_SIZE):
            parent1 = selection(population, fitnesses)
            parent2 = selection(population, fitnesses)
            parent1.crossover(parent2)
            parent1.mutation()
            nextgen_population.append(parent1)
        
        #Generational Strategy
        # Ordenar a população por fitness
        # Selecionar os melhores de acordo com o elitismo

        # Order population by fitness
        population = sorted(population, key=lambda x: fitness(x, dataset))
        nextgen_population = sorted(nextgen_population, key=lambda x: fitness(x, dataset))

        population = survivors_selection_elite(population, nextgen_population, ELISTIM) # Elitismo
        fitnesses = [fitness(population[i], dataset) for i in range(POP_SIZE)]
        best_per_generation.append(min(fitnesses))
       
        if min(fitnesses) < best_of_run_f:
                best_of_run_f = min(fitnesses)
                best_of_run_gen = gen
                best_of_run = deepcopy(population[fitnesses.index(min(fitnesses))])
                if verbose:
                    print("________________________")
                    print("gen:", gen, ", best_of_run_f:", round(min(fitnesses),3), ", best_of_run:") 
                    best_of_run.print_tree()
        if best_of_run_f <= 1e-6: 
                break   
        
    if verbose:
        print("\n\n_________________________________________________\nEND OF RUN\nbest_of_run attained at gen " + str(best_of_run_gen) +\
          " and has f=" + str(round(best_of_run_f,3)))
        best_of_run.print_tree()
    return best_per_generation, best_of_run

# %% [markdown]
# # Load DataSet

# %%
def load_dataset(file_name):
    from numpy import genfromtxt
    my_data = genfromtxt(file_name, delimiter=',')
    return my_data

# %%
dataset = load_dataset('datasetHard.csv')
print(dataset)
# Out:
# [[-1.         -0.15852902]
#  [-0.97979798 -0.09022457]
#  [-0.95959596 -0.02505046]
#  [-0.93939394  0.03706251]
#  [-0.91919192  0.09618287]
#  [-0.8989899   0.15237845]
#  [-0.87878788  0.20571648]
#  [-0.85858586  0.25626368]
#  [-0.83838384  0.30408621]
#  [-0.81818182  0.34924981]
#  [-0.7979798   0.39181978]
#  [-0.77777778  0.43186103]
#  [-0.75757576  0.46943809]
#  [-0.73737374  0.50461519]
#  [-0.71717172  0.53745624]
#  [-0.6969697   0.56802487]
#  [-0.67676768  0.59638445]
#  [-0.65656566  0.6225981 ]
#  [-0.63636364  0.64672874]
#  [-0.61616162  0.66883906]
#  [-0.5959596   0.68899158]
#  [-0.57575758  0.70724864]
#  [-0.55555556  0.7236724 ]
#  [-0.53535354  0.73832489]
#  [-0.51515152  0.75126798]
#  [-0.49494949  0.76256341]
#  [-0.47474747  0.77227281]
#  [-0.45454545  0.78045769]
#  [-0.43434343  0.78717944]
#  [-0.41414141  0.79249935]
#  [-0.39393939  0.79647863]
#  [-0.37373737  0.79917837]
#  [-0.35353535  0.80065961]
#  [-0.33333333  0.80098328]
#  [-0.31313131  0.80021025]
#  [-0.29292929  0.79840129]
#  [-0.27272727  0.79561711]
#  [-0.25252525  0.79191838]
#  [-0.23232323  0.78736565]
#  [-0.21212121  0.78201944]
#  [-0.19191919  0.7759402 ]
#  [-0.17171717  0.76918831]
#  [-0.15151515  0.76182409]
#  [-0.13131313  0.75390781]
#  [-0.11111111  0.74549965]
#  [-0.09090909  0.73665977]
#  [-0.07070707  0.72744825]
#  [-0.05050505  0.71792509]
#  [-0.03030303  0.70815027]
#  [-0.01010101  0.69818369]
#  [ 0.01010101  0.68808517]
#  [ 0.03030303  0.67791449]
#  [ 0.05050505  0.66773137]
#  [ 0.07070707  0.65759546]
#  [ 0.09090909  0.64756633]
#  [ 0.11111111  0.63770352]
#  [ 0.13131313  0.62806645]
#  [ 0.15151515  0.61871453]
#  [ 0.17171717  0.60970705]
#  [ 0.19191919  0.60110326]
#  [ 0.21212121  0.59296232]
#  [ 0.23232323  0.58534333]
#  [ 0.25252525  0.57830529]
#  [ 0.27272727  0.57190714]
#  [ 0.29292929  0.56620775]
#  [ 0.31313131  0.56126587]
#  [ 0.33333333  0.5571402 ]
#  [ 0.35353535  0.55388934]
#  [ 0.37373737  0.55157181]
#  [ 0.39393939  0.55024602]
#  [ 0.41414141  0.54997031]
#  [ 0.43434343  0.55080291]
#  [ 0.45454545  0.55280198]
#  [ 0.47474747  0.55602553]
#  [ 0.49494949  0.56053153]
#  [ 0.51515152  0.56637781]
#  [ 0.53535354  0.57362209]
#  [ 0.55555556  0.58232202]
#  [ 0.57575758  0.59253509]
#  [ 0.5959596   0.60431873]
#  [ 0.61616162  0.61773022]
#  [ 0.63636364  0.63282675]
#  [ 0.65656566  0.64966536]
#  [ 0.67676768  0.668303  ]
#  [ 0.6969697   0.68879649]
#  [ 0.71717172  0.71120252]
#  [ 0.73737374  0.73557766]
#  [ 0.75757576  0.76197836]
#  [ 0.77777778  0.79046092]
#  [ 0.7979798   0.82108152]
#  [ 0.81818182  0.8538962 ]
#  [ 0.83838384  0.88896089]
#  [ 0.85858586  0.92633134]
#  [ 0.87878788  0.9660632 ]
#  [ 0.8989899   1.00821195]
#  [ 0.91919192  1.05283295]
#  [ 0.93939394  1.0999814 ]
#  [ 0.95959596  1.14971236]
#  [ 0.97979798  1.20208074]
#  [ 1.          1.2571413 ]]

# %%
best_by_generation, overall_best = standard_gp(dataset, verbose=True)
# Out:
# 64
# 50
# bloat control: 0.05
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.1
# bloat control: 0.04
# bloat control: 0.11
# bloat control: 0.08
# bloat control: 0.06
# bloat control: 0.1
# bloat control: 0.13
# bloat control: 0.12
# bloat control: 0.12
# bloat control: 0.08
# bloat control: 0.13
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.11
# bloat control: 0.11
# bloat control: 0.13
# bloat control: 0.1
# bloat control: 0.08
# bloat control: 0.24
# bloat control: 0.26
# bloat control: 0.2
# bloat control: 0.19
# bloat control: 0.17
# bloat control: 0.12
# bloat control: 0.24
# bloat control: 0.25
# bloat control: 0.14
# bloat control: 0.12
# bloat control: 0.05
# bloat control: 0.13
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.14
# bloat control: 0.18
# bloat control: 0.26
# bloat control: 0.29
# bloat control: 0.46
# bloat control: 0.46
# bloat control: 0.22
# bloat control: 0.16
# bloat control: 0.24
# bloat control: 0.22
# bloat control: 0.29
# bloat control: 0.04
# Generation: 0
# bloat control: 0.05
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.1
# bloat control: 0.04
# bloat control: 0.11
# bloat control: 0.08
# bloat control: 0.06
# bloat control: 0.1
# bloat control: 0.13
# bloat control: 0.12
# bloat control: 0.12
# bloat control: 0.08
# bloat control: 0.13
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.11
# bloat control: 0.11
# bloat control: 0.13
# bloat control: 0.1
# bloat control: 0.08
# bloat control: 0.24
# bloat control: 0.26
# bloat control: 0.2
# bloat control: 0.19
# bloat control: 0.17
# bloat control: 0.12
# bloat control: 0.24
# bloat control: 0.25
# bloat control: 0.14
# bloat control: 0.12
# bloat control: 0.05
# bloat control: 0.13
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.14
# bloat control: 0.18
# bloat control: 0.26
# bloat control: 0.29
# bloat control: 0.46
# bloat control: 0.46
# bloat control: 0.22
# bloat control: 0.16
# bloat control: 0.24
# bloat control: 0.22
# bloat control: 0.29
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.26
# bloat control: 0.14
# bloat control: 0.18
# bloat control: 0.26
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.1
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.11
# bloat control: 0.12
# bloat control: 0.26
# bloat control: 0.16
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.03
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.12
# bloat control: 0.03
# bloat control: 0.16
# bloat control: 0.09
# bloat control: 0.1
# bloat control: 0.21
# bloat control: 0.06
# bloat control: 0.01
# bloat control: 0.36
# bloat control: 0.08
# bloat control: 0.39
# bloat control: 0.15
# bloat control: 0.35
# bloat control: 0.08
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.37
# bloat control: 0.05
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.13
# bloat control: 0.11
# bloat control: 0.11
# bloat control: 0.28
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.11
# bloat control: 0.04
# bloat control: 0.12
# bloat control: 0.05
# bloat control: 0.1
# bloat control: 0.01
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.11
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.12
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.09
# bloat control: 0.26
# bloat control: 0.13
# bloat control: 0.11
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.14
# bloat control: 0.26
# bloat control: 0.18
# bloat control: 0.37
# bloat control: 0.28
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.12
# bloat control: 0.15
# bloat control: 0.35
# bloat control: 0.03
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.11
# bloat control: 0.39
# bloat control: 0.21
# ________________________
# gen: 0 , best_of_run_f: 0.214 , best_of_run:
# log
#    sqrt
#       add
#          2
#          2
# Generation: 1
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.11
# bloat control: 0.04
# bloat control: 0.12
# bloat control: 0.05
# bloat control: 0.1
# bloat control: 0.01
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.11
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.12
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.09
# bloat control: 0.26
# bloat control: 0.13
# bloat control: 0.11
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.14
# bloat control: 0.26
# bloat control: 0.18
# bloat control: 0.37
# bloat control: 0.28
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.12
# bloat control: 0.15
# bloat control: 0.35
# bloat control: 0.03
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.11
# bloat control: 0.39
# bloat control: 0.21
# bloat control: 0.01
# bloat control: 0.19
# bloat control: 0.1
# bloat control: 0.04
# bloat control: 0.15
# bloat control: 0.17
# bloat control: 0.04
# bloat control: 0.24
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.15
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.12
# bloat control: 0.03
# bloat control: 0.14
# bloat control: 0.16
# bloat control: 0.01
# bloat control: 0.19
# bloat control: 0.1
# bloat control: 0.12
# bloat control: 0.05
# bloat control: 0.08
# bloat control: 0.09
# bloat control: 0.08
# bloat control: 0.18
# bloat control: 0.13
# bloat control: 0.39
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.05
# bloat control: 0.16
# bloat control: 0.13
# bloat control: 0.26
# bloat control: 0.24
# bloat control: 0.04
# bloat control: 0.01
# bloat control: 0.13
# bloat control: 0.08
# bloat control: 0.22
# bloat control: 0.11
# bloat control: 0.02
# bloat control: 0.17
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.22
# bloat control: 0.01
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.11
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.11
# bloat control: 0.17
# bloat control: 0.01
# bloat control: 0.22
# bloat control: 0.15
# bloat control: 0.1
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.03
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.12
# bloat control: 0.13
# bloat control: 0.16
# bloat control: 0.16
# bloat control: 0.26
# bloat control: 0.19
# bloat control: 0.39
# bloat control: 0.13
# bloat control: 0.14
# bloat control: 0.18
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.04
# bloat control: 0.13
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.12
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.09
# bloat control: 0.19
# bloat control: 0.22
# bloat control: 0.24
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.15
# bloat control: 0.24
# ________________________
# gen: 1 , best_of_run_f: 0.184 , best_of_run:
# log
#    2
# Generation: 2
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.11
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.11
# bloat control: 0.17
# bloat control: 0.01
# bloat control: 0.22
# bloat control: 0.15
# bloat control: 0.1
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.03
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.12
# bloat control: 0.13
# bloat control: 0.16
# bloat control: 0.16
# bloat control: 0.26
# bloat control: 0.19
# bloat control: 0.39
# bloat control: 0.13
# bloat control: 0.14
# bloat control: 0.18
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.04
# bloat control: 0.13
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.12
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.09
# bloat control: 0.19
# bloat control: 0.22
# bloat control: 0.24
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.15
# bloat control: 0.24
# bloat control: 0.03
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.22
# bloat control: 0.15
# bloat control: 0.37
# bloat control: 0.13
# bloat control: 0.05
# bloat control: 0.12
# bloat control: 0.19
# bloat control: 0.11
# bloat control: 0.04
# bloat control: 0.1
# bloat control: 0.14
# bloat control: 0.03
# bloat control: 0.01
# bloat control: 0.11
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.07
# bloat control: 0.12
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.21
# bloat control: 0.04
# bloat control: 0.09
# bloat control: 0.06
# bloat control: 0.09
# bloat control: 0.11
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.13
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.17
# bloat control: 0.06
# bloat control: 0.11
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.1
# bloat control: 0.16
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.11
# bloat control: 0.13
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.07
# bloat control: 0.09
# bloat control: 0.16
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.37
# bloat control: 0.11
# bloat control: 0.11
# bloat control: 0.12
# bloat control: 0.06
# bloat control: 0.19
# bloat control: 0.04
# bloat control: 0.14
# bloat control: 0.05
# bloat control: 0.17
# bloat control: 0.15
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.1
# bloat control: 0.1
# bloat control: 0.11
# bloat control: 0.12
# bloat control: 0.13
# bloat control: 0.21
# bloat control: 0.22
# Generation: 3
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.11
# bloat control: 0.13
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.07
# bloat control: 0.09
# bloat control: 0.16
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.37
# bloat control: 0.11
# bloat control: 0.11
# bloat control: 0.12
# bloat control: 0.06
# bloat control: 0.19
# bloat control: 0.04
# bloat control: 0.14
# bloat control: 0.05
# bloat control: 0.17
# bloat control: 0.15
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.1
# bloat control: 0.1
# bloat control: 0.11
# bloat control: 0.12
# bloat control: 0.13
# bloat control: 0.21
# bloat control: 0.22
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.03
# bloat control: 0.22
# bloat control: 0.34
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.09
# bloat control: 0.03
# bloat control: 0.22
# bloat control: 0.02
# bloat control: 0.12
# bloat control: 0.14
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.01
# bloat control: 0.05
# bloat control: 0.04
# bloat control: 0.08
# bloat control: 0.09
# bloat control: 0.09
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.01
# bloat control: 0.03
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.07
# bloat control: 0.05
# bloat control: 0.04
# bloat control: 0.14
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.1
# bloat control: 0.01
# bloat control: 0.11
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.09
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.05
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.1
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.06
# bloat control: 0.09
# bloat control: 0.22
# bloat control: 0.05
# bloat control: 0.11
# bloat control: 0.08
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.09
# bloat control: 0.14
# bloat control: 0.14
# bloat control: 0.04
# bloat control: 0.22
# bloat control: 0.12
# Generation: 4
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.09
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.05
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.1
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.06
# bloat control: 0.09
# bloat control: 0.22
# bloat control: 0.05
# bloat control: 0.11
# bloat control: 0.08
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.09
# bloat control: 0.14
# bloat control: 0.14
# bloat control: 0.04
# bloat control: 0.22
# bloat control: 0.12
# bloat control: 0.04
# bloat control: 0.18
# bloat control: 0.02
# bloat control: 0.01
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.29
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.17
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.01
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.01
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.17
# bloat control: 0.18
# Generation: 5
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.01
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.01
# bloat control: 0.01
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.17
# bloat control: 0.18
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# Generation: 6
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.01
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.01
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.08
# Generation: 7
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.03
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.08
# Generation: 8
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.08
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.07
# Generation: 9
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.03
# bloat control: 0.03
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# Generation: 10
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.03
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# Generation: 11
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.03
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# Generation: 12
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# Generation: 13
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.06
# Generation: 14
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.05
# Generation: 15
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.03
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# ...
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# Generation: 95
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# Generation: 96
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.08
# Generation: 97
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# Generation: 98
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# Generation: 99
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.06
# bloat control: 0.06
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.07
# bloat control: 0.08
# bloat control: 0.07
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.07
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.08
# bloat control: 0.06
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.05
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.02
# bloat control: 0.04
# bloat control: 0.04
# bloat control: 0.05
# bloat control: 0.08
# bloat control: 0.08
# bloat control: 0.05
# bloat control: 0.05
# bloat control: 0.06
# bloat control: 0.03
# bloat control: 0.04
#
#
# _________________________________________________
# END OF RUN
# best_of_run attained at gen 1 and has f=0.184
# log
#    2

# %%
overall_best.print_tree()
erro = calculate_error(overall_best,dataset)
print(erro)
# Out:
# log
#    2
# 0.1640277560219997

# %%
generations = list(range(len(best_by_generation)))
plt.plot(generations, best_by_generation, label='Best by Generation')
plt.title('Performance over generations')
plt.xlabel('Generation')
plt.ylabel('Fitness')
plt.legend(loc='best')
plt.show()
